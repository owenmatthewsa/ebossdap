# %%
# Imports
import sys
import os
import numpy as np
import pandas as pd
from astropy.io import fits
import astropy.coordinates as acoords
from astropy.io import fits
import glob
from matplotlib import pyplot as plt
np.set_printoptions(suppress=True)
import time
from IPython import embed
import astropy.constants


from pathlib import Path

hdu = fits.open(str(Path().absolute())+r"\summary_files\eBOSS_DAP_emlines_full_v12.fit")
hdu2 = fits.open(str(Path().absolute())+r"\summary_files\eboss_dr17_summary_odtrim8_v1.fit")

# %%
#checking total length for debugging
#len(hdu[1].data['Z'])

# %%
#checking the columns for debugging
#hdu2[1].columns

# %%
#checking the columns for debugging
hdu[1].columns
# Out:
# ColDefs(
#     name = 'PMF_String'; format = '16A'
#     name = 'PLATE'; format = 'K'
#     name = 'MJD'; format = 'K'
#     name = 'FIBER'; format = 'K'
#     name = 'Z'; format = 'D'
#     name = 'SC_VELOCITY'; format = 'D'
#     name = 'SC_VELOCITY_ERR'; format = 'D'
#     name = 'SC_DISPERSION'; format = 'D'
#     name = 'SC_DISPERSION_ERR'; format = 'D'
#     name = 'SC_CORRECTION'; format = 'D'
#     name = 'SNR'; format = 'D'
#     name = 'MGII_2796_FLUX'; format = 'D'
#     name = 'MGII_2796_FLUX_ERR'; format = 'D'
#     name = 'MGII_2796_EW'; format = 'D'
#     name = 'MGII_2796_EW_ERR'; format = 'D'
#     name = 'MGII_2796_INT_EW'; format = 'D'
#     name = 'MGII_2796_INT_EW_ERR'; format = 'D'
#     name = 'MGII_2796_SIGMA'; format = 'D'
#     name = 'MGII_2796_SIGMA_ERR'; format = 'D'
#     name = 'MGII_2796_SIGMA_CORR'; format = 'D'
#     name = 'MGII_2803_FLUX'; format = 'D'
#     name = 'MGII_2803_FLUX_ERR'; format = 'D'
#     name = 'MGII_2803_EW'; format = 'D'
# ...

# %%
OII_3727 = hdu[1].data['OII_3727_FLUX'].byteswap().newbyteorder()
OII_3727_err= hdu[1].data['OII_3727_FLUX_ERR'].byteswap().newbyteorder()
OII_3729 = hdu[1].data['OII_3729_FLUX'].byteswap().newbyteorder()
OII_3729_err= hdu[1].data['OII_3729_FLUX_ERR'].byteswap().newbyteorder()
#H12 = hdu[1].data['H12_FLUX'].byteswap().newbyteorder()
#H12_err= hdu[1].data['H12_FLUX_ERR'].byteswap().newbyteorder()
#H11 = hdu[1].data['H11_FLUX'].byteswap().newbyteorder()
#H11_err= hdu[1].data['H11_FLUX_ERR'].byteswap().newbyteorder()
#Hthe = hdu[1].data['H_theta_FLUX'].byteswap().newbyteorder()
#Hthe_err= hdu[1].data['H_theta_FLUX_ERR'].byteswap().newbyteorder()
#Heta = hdu[1].data['H_eta_FLUX'].byteswap().newbyteorder()
#Heta_err= hdu[1].data['H_eta_FLUX_ERR'].byteswap().newbyteorder()
NeIII_3869 = hdu[1].data['NeIII_3870_FLUX'].byteswap().newbyteorder()
NeIII_3869_err= hdu[1].data['NeIII_3870_FLUX_ERR'].byteswap().newbyteorder()
#HeI_3889 = hdu[1].data['HeI_3890_FLUX'].byteswap().newbyteorder()
#HeI_3889_err= hdu[1].data['HeI_3890_FLUX_ERR'].byteswap().newbyteorder()
#Hzet = hdu[1].data['H_zeta_FLUX'].byteswap().newbyteorder()
#Hzet_err= hdu[1].data['H_zeta_FLUX_ERR'].byteswap().newbyteorder()
NeIII_3968 = hdu[1].data['NeIII_3969_FLUX'].byteswap().newbyteorder()
NeIII_3968_err= hdu[1].data['NeIII_3969_FLUX_ERR'].byteswap().newbyteorder()
#Heps = hdu[1].data['H_epsilon_FLUX'].byteswap().newbyteorder()
#Heps_err= hdu[1].data['H_epsilon_FLUX_ERR'].byteswap().newbyteorder()
#Hdel = hdu[1].data['H_delta_FLUX'].byteswap().newbyteorder()
#Hdel_err= hdu[1].data['H_delta_FLUX_ERR'].byteswap().newbyteorder()
#Hgam = hdu[1].data['H_gamma_FLUX'].byteswap().newbyteorder()
#Hgam_err= hdu[1].data['H_gamma_FLUX_ERR'].byteswap().newbyteorder()
HeII_4687 = hdu[1].data['HeII_4687_FLUX'].byteswap().newbyteorder()
HeII_4687_err= hdu[1].data['HeII_4687_FLUX_ERR'].byteswap().newbyteorder()
Hb = hdu[1].data['H_beta_FLUX'].byteswap().newbyteorder()
Hb_err= hdu[1].data['H_beta_FLUX_ERR'].byteswap().newbyteorder()
OIII_4960 = hdu[1].data['OIII_4960_FLUX'].byteswap().newbyteorder()
OIII_4960_err= hdu[1].data['OIII_4960_FLUX_ERR'].byteswap().newbyteorder()
OIII_5008 = hdu[1].data['OIII_5008_FLUX'].byteswap().newbyteorder()
OIII_5008_err= hdu[1].data['OIII_5008_FLUX_ERR'].byteswap().newbyteorder()
#NI_5199 = hdu[1].data['NI_5199_FLUX'].byteswap().newbyteorder()
#NI_5199_err= hdu[1].data['NI_5199_FLUX_ERR'].byteswap().newbyteorder()
#NI_5201 = hdu[1].data['NI_5202_FLUX'].byteswap().newbyteorder()
#NI_5201_err= hdu[1].data['NI_5202_FLUX_ERR'].byteswap().newbyteorder()
HeI_5877 = hdu[1].data['HeI_5877_FLUX'].byteswap().newbyteorder()
HeI_5877_err= hdu[1].data['HeI_5877_FLUX_ERR'].byteswap().newbyteorder()
OI_6302 = hdu[1].data['OI_6302_FLUX'].byteswap().newbyteorder()
OI_6302_err= hdu[1].data['OI_6302_FLUX_ERR'].byteswap().newbyteorder()
OI_6365 = hdu[1].data['OI_6366_FLUX'].byteswap().newbyteorder()
OI_6365_err= hdu[1].data['OI_6366_FLUX_ERR'].byteswap().newbyteorder()
NII_6549 = hdu[1].data['NII_6550_FLUX'].byteswap().newbyteorder()
NII_6549_err= hdu[1].data['NII_6550_FLUX_ERR'].byteswap().newbyteorder()
Ha = hdu[1].data['H_alpha_FLUX'].byteswap().newbyteorder()
Ha_err= hdu[1].data['H_alpha_FLUX_ERR'].byteswap().newbyteorder()
NII_6585 = hdu[1].data['NII_6585_FLUX'].byteswap().newbyteorder()
NII_6585_err= hdu[1].data['NII_6585_FLUX_ERR'].byteswap().newbyteorder()
SII_6718 = hdu[1].data['SII_6718_FLUX'].byteswap().newbyteorder()
SII_6718_err= hdu[1].data['SII_6718_FLUX_ERR'].byteswap().newbyteorder()
SII_6732 = hdu[1].data['SII_6733_FLUX'].byteswap().newbyteorder()
SII_6732_err= hdu[1].data['SII_6733_FLUX_ERR'].byteswap().newbyteorder()
#HeI_7067 = hdu[1].data['HeI_7068_FLUX'].byteswap().newbyteorder()
#HeI_7067_err= hdu[1].data['HeI_7068_FLUX_ERR'].byteswap().newbyteorder()
#ArIII_7137 = hdu[1].data['ArIII_7138_FLUX'].byteswap().newbyteorder()
#ArIII_7137_err= hdu[1].data['ArIII_7138_FLUX_ERR'].byteswap().newbyteorder()
#ArIII_7753 = hdu[1].data['ArIII_7753_FLUX'].byteswap().newbyteorder()
#ArIII_7753_err= hdu[1].data['ArIII_7753_FLUX_ERR'].byteswap().newbyteorder()
#Peta = hdu[1].data['P_eta_FLUX'].byteswap().newbyteorder()
#Peta_err= hdu[1].data['P_eta_FLUX_ERR'].byteswap().newbyteorder()
SIII_9071 = hdu[1].data['SIII_9071_FLUX'].byteswap().newbyteorder()
SIII_9071_err= hdu[1].data['SIII_9071_FLUX_ERR'].byteswap().newbyteorder()
#Pzet = hdu[1].data['P_zeta_FLUX'].byteswap().newbyteorder()
#Pzet_err= hdu[1].data['P_zeta_FLUX_ERR'].byteswap().newbyteorder()
SIII_9533 = hdu[1].data['SIII_9533_FLUX'].byteswap().newbyteorder()
SIII_9533_err= hdu[1].data['SIII_9533_FLUX_ERR'].byteswap().newbyteorder()
#Peps = hdu[1].data['P_epsilon_FLUX'].byteswap().newbyteorder()
#Peps_err= hdu[1].data['P_epsilon_FLUX_ERR'].byteswap().newbyteorder()
#CIII_1906 = hdu[1].data['CIII_1906_FLUX'].byteswap().newbyteorder()
#CIII_1906_err= hdu[1].data['CIII_1906_FLUX_ERR'].byteswap().newbyteorder()
#CIII_1909 = hdu[1].data['CIII_1909_FLUX'].byteswap().newbyteorder()
#CIII_1909_err= hdu[1].data['CIII_1909_FLUX_ERR'].byteswap().newbyteorder()
#CII_2325C = hdu[1].data['CII_2325C_FLUX'].byteswap().newbyteorder()
#CII_2325C_err= hdu[1].data['CII_2325C_FLUX_ERR'].byteswap().newbyteorder()
#CII_2325D = hdu[1].data['CII_2325D_FLUX'].byteswap().newbyteorder()
#CII_2325D_err= hdu[1].data['CII_2325D_FLUX_ERR'].byteswap().newbyteorder()
#CII_2328 = hdu[1].data['CII_2328_FLUX'].byteswap().newbyteorder()
#CII_2328_err= hdu[1].data['CII_2328_FLUX_ERR'].byteswap().newbyteorder()
#FEIISTAR_2365 = hdu[1].data['FEIISTAR_2365_FLUX'].byteswap().newbyteorder()
#FEIISTAR_2365_err= hdu[1].data['FEIISTAR_2365_FLUX_ERR'].byteswap().newbyteorder()
#FEIISTAR_2396 = hdu[1].data['FEIISTAR_2396_FLUX'].byteswap().newbyteorder()
#FEIISTAR_2396_err= hdu[1].data['FEIISTAR_2396_FLUX_ERR'].byteswap().newbyteorder()
#NEIV_2423 = hdu[1].data['NEIV_2423_FLUX'].byteswap().newbyteorder()
#NEIV_2423_err= hdu[1].data['NEIV_2423_FLUX_ERR'].byteswap().newbyteorder()
#NEIV_2425 = hdu[1].data['NEIV_2425_FLUX'].byteswap().newbyteorder()
#NEIV_2425_err= hdu[1].data['NEIV_2425_FLUX_ERR'].byteswap().newbyteorder()
#OII_2470 = hdu[1].data['OII_2470_FLUX'].byteswap().newbyteorder()
#OII_2470_err= hdu[1].data['OII_2470_FLUX_ERR'].byteswap().newbyteorder()
#FEIISTAR_2613 = hdu[1].data['FEIISTAR_2613_FLUX'].byteswap().newbyteorder()
#FEIISTAR_2613_err= hdu[1].data['FEIISTAR_2613_FLUX_ERR'].byteswap().newbyteorder()
#FEIISTAR_2626 = hdu[1].data['FEIISTAR_2626_FLUX'].byteswap().newbyteorder()
#FEIISTAR_2626_err= hdu[1].data['FEIISTAR_2626_FLUX_ERR'].byteswap().newbyteorder()
#FEIISTAR_2632 = hdu[1].data['FEIISTAR_2632_FLUX'].byteswap().newbyteorder()
#FEIISTAR_2632_err= hdu[1].data['FEIISTAR_2632_FLUX_ERR'].byteswap().newbyteorder()
MGII_2796 = hdu[1].data['MGII_2796_FLUX'].byteswap().newbyteorder()
MGII_2796_err= hdu[1].data['MGII_2796_FLUX_ERR'].byteswap().newbyteorder()
MGII_2803 = hdu[1].data['MGII_2803_FLUX'].byteswap().newbyteorder()
MGII_2803_err= hdu[1].data['MGII_2803_FLUX_ERR'].byteswap().newbyteorder()
#HEI_2945 = hdu[1].data['HEI_2945_FLUX'].byteswap().newbyteorder()
#HEI_2945_err= hdu[1].data['HEI_2945_FLUX_ERR'].byteswap().newbyteorder()
#OIII_3134 = hdu[1].data[ 'OIII_3134_FLUX'].byteswap().newbyteorder()
#OIII_3134_err= hdu[1].data['OIII_3134_FLUX_ERR'].byteswap().newbyteorder() 
#HeI_3189 = hdu[1].data['HeI_3189_FLUX'].byteswap().newbyteorder()
#HeI_3189_err= hdu[1].data['HeI_3189_FLUX_ERR'].byteswap().newbyteorder() 
#HeII_3204 = hdu[1].data['HeII_3204_FLUX'].byteswap().newbyteorder()
#HeII_3204_err= hdu[1].data['HeII_3204_FLUX_ERR'].byteswap().newbyteorder() 
NeV_3347 = hdu[1].data['NeV_3347_FLUX'].byteswap().newbyteorder()
NeV_3347_err= hdu[1].data['NeV_3347_FLUX_ERR'].byteswap().newbyteorder() 
NeV_3427 = hdu[1].data['NeV_3427_FLUX'].byteswap().newbyteorder()
NeV_3427_err= hdu[1].data['NeV_3427_FLUX_ERR'].byteswap().newbyteorder() 
#SII_4070 = hdu[1].data['SII_4070_FLUX'].byteswap().newbyteorder()
#SII_4070_err= hdu[1].data['SII_4070_FLUX_ERR'].byteswap().newbyteorder() 
OIII_4364 = hdu[1].data['OIII_4364_FLUX'].byteswap().newbyteorder()
OIII_4364_err= hdu[1].data['OIII_4364_FLUX_ERR'].byteswap().newbyteorder() 
#HeI_4473 = hdu[1].data['HeI_4473_FLUX'].byteswap().newbyteorder()
#HeI_4473_err= hdu[1].data['HeI_4473_FLUX_ERR'].byteswap().newbyteorder() 
#FeIII_4659 = hdu[1].data['FeIII_4659_FLUX'].byteswap().newbyteorder()
#FeIII_4659_err= hdu[1].data['FeIII_4659_FLUX_ERR'].byteswap().newbyteorder()

# %%
#making the arrays for our new Dataframes
NII =  hdu[1].data['NII_6585_FLUX'].byteswap().newbyteorder()
Halpha = hdu[1].data['H_alpha_FLUX'].byteswap().newbyteorder()
OIII = hdu[1].data['OIII_5008_FLUX'].byteswap().newbyteorder()
Hbeta = hdu[1].data['H_beta_FLUX'].byteswap().newbyteorder()
OII_3726 = hdu[1].data['OII_3727_FLUX'].byteswap().newbyteorder()
OII_3729 = hdu[1].data['OII_3729_FLUX'].byteswap().newbyteorder()
NeV_3427 = hdu[1].data['NEV_3427_FLUX'].byteswap().newbyteorder()
NeV_3347 = hdu[1].data['NEV_3347_FLUX'].byteswap().newbyteorder()
OIII_4364 = hdu[1].data['OIII_4364_FLUX'].byteswap().newbyteorder()
HeII_4687 = hdu[1].data['HeII_4687_FLUX'].byteswap().newbyteorder()




lines = ['Hb', 'NeV','OII','NII_6585','OIII_5008','Ha','OIII_4364', 'HeII_4687']

Hb_ew = hdu[1].data['H_beta_EW'].byteswap().newbyteorder()
Hb_ew_err= hdu[1].data['H_beta_EW_ERR'].byteswap().newbyteorder()
NeV_3427_ew = hdu[1].data['NEV_3427_EW'].byteswap().newbyteorder()
NeV_3347_ew = hdu[1].data['NEV_3347_EW'].byteswap().newbyteorder()
NeV_3427_ew_err = hdu[1].data['NEV_3427_EW_err'].byteswap().newbyteorder()
NeV_3347_ew_err = hdu[1].data['NEV_3347_EW_err'].byteswap().newbyteorder()
OII_3726_ew = hdu[1].data['OII_3727_EW'].byteswap().newbyteorder()
OII_3729_ew = hdu[1].data['OII_3729_EW'].byteswap().newbyteorder()
OII_3726_ew_err = hdu[1].data['OII_3727_EW_ERR'].byteswap().newbyteorder()
OII_3729_ew_err = hdu[1].data['OII_3729_EW_ERR'].byteswap().newbyteorder()
NII_6585_ew = hdu[1].data['NII_6585_EW'].byteswap().newbyteorder()
NII_6585_ew_err= hdu[1].data['NII_6585_EW_ERR'].byteswap().newbyteorder()
OIII_5008_ew = hdu[1].data['OIII_5008_EW'].byteswap().newbyteorder()
OIII_5008_ew_err= hdu[1].data['OIII_5008_EW_ERR'].byteswap().newbyteorder()
Ha_ew = hdu[1].data['H_alpha_EW'].byteswap().newbyteorder()
Ha_ew_err= hdu[1].data['H_alpha_EW_ERR'].byteswap().newbyteorder()
OIII_4364_ew = hdu[1].data['OIII_4364_EW'].byteswap().newbyteorder()
OIII_4364_ew_err= hdu[1].data['OIII_4364_EW_ERR'].byteswap().newbyteorder()
HeII_4687_ew = hdu[1].data['HeII_4687_EW'].byteswap().newbyteorder()
HeII_4687_ew_err= hdu[1].data['HeII_4687_EW_ERR'].byteswap().newbyteorder()

NeV = NeV_3347+NeV_3427
NeV_ew = NeV_3347_ew+NeV_3427_ew
NeV_err = np.sqrt((NeV_3347_err**2)+(NeV_3427_err**2))
NeV_ew_err = np.sqrt((NeV_3347_ew_err**2)+(NeV_3427_ew_err**2))

OII_ew = OII_3726_ew+OII_3729_ew
OII_ew_err = np.sqrt((OII_3726_ew_err**2)+(OII_3729_ew_err**2))



z = hdu[1].data['Z'].byteswap().newbyteorder()

#plate_me = hdu[1].data['PLATE'].byteswap().newbyteorder()
#mjd_me = hdu[1].data['MJD'].byteswap().newbyteorder()
#fiber_me = hdu[1].data['FIBER'].byteswap().newbyteorder()
plate = hdu[1].data['plate'].byteswap().newbyteorder()
mjd = hdu[1].data['mjd'].byteswap().newbyteorder()
fiber = hdu[1].data['fiber'].byteswap().newbyteorder()




#dataframe creation of MY data
OII_3727 = hdu[1].data['OII_3727_FLUX'].byteswap().newbyteorder()
OII_3727_err= hdu[1].data['OII_3727_FLUX_ERR'].byteswap().newbyteorder()
OII_3729 = hdu[1].data['OII_3729_FLUX'].byteswap().newbyteorder()
OII_3729_err= hdu[1].data['OII_3729_FLUX_ERR'].byteswap().newbyteorder()
NeIII_3869 = hdu[1].data['NeIII_3870_FLUX'].byteswap().newbyteorder()
NeIII_3869_err= hdu[1].data['NeIII_3870_FLUX_ERR'].byteswap().newbyteorder()
NeIII_3968 = hdu[1].data['NeIII_3969_FLUX'].byteswap().newbyteorder()
NeIII_3968_err= hdu[1].data['NeIII_3969_FLUX_ERR'].byteswap().newbyteorder()
HeII_4687 = hdu[1].data['HeII_4687_FLUX'].byteswap().newbyteorder()
HeII_4687_err= hdu[1].data['HeII_4687_FLUX_ERR'].byteswap().newbyteorder()
Hb = hdu[1].data['H_beta_FLUX'].byteswap().newbyteorder()
Hb_err= hdu[1].data['H_beta_FLUX_ERR'].byteswap().newbyteorder()
OIII_4960 = hdu[1].data['OIII_4960_FLUX'].byteswap().newbyteorder()
OIII_4960_err= hdu[1].data['OIII_4960_FLUX_ERR'].byteswap().newbyteorder()
OIII_5008 = hdu[1].data['OIII_5008_FLUX'].byteswap().newbyteorder()
OIII_5008_err= hdu[1].data['OIII_5008_FLUX_ERR'].byteswap().newbyteorder()
HeI_5877 = hdu[1].data['HeI_5877_FLUX'].byteswap().newbyteorder()
HeI_5877_err= hdu[1].data['HeI_5877_FLUX_ERR'].byteswap().newbyteorder()
OI_6302 = hdu[1].data['OI_6302_FLUX'].byteswap().newbyteorder()
OI_6302_err= hdu[1].data['OI_6302_FLUX_ERR'].byteswap().newbyteorder()
OI_6365 = hdu[1].data['OI_6366_FLUX'].byteswap().newbyteorder()
OI_6365_err= hdu[1].data['OI_6366_FLUX_ERR'].byteswap().newbyteorder()
NII_6549 = hdu[1].data['NII_6550_FLUX'].byteswap().newbyteorder()
NII_6549_err= hdu[1].data['NII_6550_FLUX_ERR'].byteswap().newbyteorder()
Ha = hdu[1].data['H_alpha_FLUX'].byteswap().newbyteorder()
Ha_err= hdu[1].data['H_alpha_FLUX_ERR'].byteswap().newbyteorder()
NII_6585 = hdu[1].data['NII_6585_FLUX'].byteswap().newbyteorder()
NII_6585_err= hdu[1].data['NII_6585_FLUX_ERR'].byteswap().newbyteorder()
SII_6718 = hdu[1].data['SII_6718_FLUX'].byteswap().newbyteorder()
SII_6718_err= hdu[1].data['SII_6718_FLUX_ERR'].byteswap().newbyteorder()
SII_6732 = hdu[1].data['SII_6733_FLUX'].byteswap().newbyteorder()
SII_6732_err= hdu[1].data['SII_6733_FLUX_ERR'].byteswap().newbyteorder()
SIII_9071 = hdu[1].data['SIII_9071_FLUX'].byteswap().newbyteorder()
SIII_9071_err= hdu[1].data['SIII_9071_FLUX_ERR'].byteswap().newbyteorder()
SIII_9533 = hdu[1].data['SIII_9533_FLUX'].byteswap().newbyteorder()
SIII_9533_err= hdu[1].data['SIII_9533_FLUX_ERR'].byteswap().newbyteorder()
MGII_2796 = hdu[1].data['MGII_2796_FLUX'].byteswap().newbyteorder()
MGII_2796_err= hdu[1].data['MGII_2796_FLUX_ERR'].byteswap().newbyteorder()
MGII_2803 = hdu[1].data['MGII_2803_FLUX'].byteswap().newbyteorder()
MGII_2803_err= hdu[1].data['MGII_2803_FLUX_ERR'].byteswap().newbyteorder()
NeV_3347 = hdu[1].data['NeV_3347_FLUX'].byteswap().newbyteorder()
NeV_3347_err= hdu[1].data['NeV_3347_FLUX_ERR'].byteswap().newbyteorder() 
NeV_3427 = hdu[1].data['NeV_3427_FLUX'].byteswap().newbyteorder()
NeV_3427_err= hdu[1].data['NeV_3427_FLUX_ERR'].byteswap().newbyteorder() 
OIII_4364 = hdu[1].data['OIII_4364_FLUX'].byteswap().newbyteorder()
OIII_4364_err= hdu[1].data['OIII_4364_FLUX_ERR'].byteswap().newbyteorder() 

disp = hdu[1].data['SC_DISPERSION'].byteswap().newbyteorder()
disp_err= hdu[1].data['SC_DISPERSION_ERR'].byteswap().newbyteorder() 

dfV12 = pd.DataFrame({'plate':plate,'mjd':mjd,'fiber':fiber,'OII_3727':OII_3727,'OII_3727_err':OII_3727_err,'OII_3729':OII_3729,
                       'OII_3729_err':OII_3729_err,'NeIII_3869':NeIII_3869,'NeIII_3869_err':NeIII_3869_err,
                       'HeII_4687':HeII_4687,'HeII_4687_err':HeII_4687_err,'Hb':Hb,'Hb_err':Hb_err,
                       'OIII_4960':OIII_4960,'OIII_4960_err':OIII_4960_err,'OIII_5008':OIII_5008,
                       'OIII_5008_err':OIII_5008_err,'HeI_5877':HeI_5877,'HeI_5877_err':HeI_5877_err,
                       'OI_6302':OI_6302,'OI_6302_err':OI_6302_err,'OI_6365':OI_6365,'OI_6365_err':OI_6365_err,
                       'NII_6549':NII_6549,'NII_6549_err':NII_6549_err,'Ha':Ha,'Ha_err':Ha_err,'NII_6585':NII_6585,
                       'NII_6585_err':NII_6585_err,'SII_6718':SII_6718,'SII_6718_err':SII_6718_err,'SII_6732':SII_6732,
                       'SII_6732_err':SII_6732_err,'SIII_9071':SIII_9071,'SIII_9071_err':SIII_9071_err,'SIII_9533':SIII_9533,
                       'SIII_9533_err':SIII_9533_err,'MGII_2796':MGII_2796,'MGII_2796_err':MGII_2796_err,'MGII_2803':MGII_2803,
                       'MGII_2803_err':MGII_2803_err,'NeV_3347':NeV_3347,
                       'NeV_3347_err':NeV_3347_err ,'NeV_3427':NeV_3427,'NeV_3427_err':NeV_3427_err ,'OIII_4364':OIII_4364,
                       'OIII_4364_err':OIII_4364_err ,'z':z,'NeV':NeV,'NeV_err':NeV_err,
                       'Hb_ew':Hb_ew,'Hb_ew_err':Hb_ew_err,'NII_6585_ew':NII_6585_ew,'NII_6585_ew_err':NII_6585_ew_err,
                       'OIII_5008_ew':OIII_5008_ew,'OIII_5008_ew_err':OIII_5008_ew_err,'Ha_ew':Ha_ew,
                       'Ha_ew_err':Ha_ew_err,'OIII_4364_ew':OIII_4364_ew,'OIII_4364_ew_err':OIII_4364_ew_err,
                       'HeII_4687_ew':HeII_4687_ew,'HeII_4687_ew_err':HeII_4687_ew_err,'NeV_ew':NeV_ew,
                       'NeV_ew_err':NeV_ew_err,'OII_ew':OII_ew,'OII_ew_err':OII_ew_err,'disp':disp,'disp_err':disp_err})



r'''dfV8 = pd.DataFrame({'plate':plate,'mjd':mjd,'fiber':fiber,'OII_3727':OII_3727,'OII_3727_err':OII_3727_err,'OII_3729':OII_3729,
                       'OII_3729_err':OII_3729_err,'H12':H12,'H12_err':H12_err,'H11':H11,'H11_err':H11_err,
                       'Hthe':Hthe,'Hthe_err':Hthe_err,'Heta':Heta,'Heta_err':Heta_err,'NeIII_3869':NeIII_3869,
                       'NeIII_3869_err':NeIII_3869_err,'HeI_3889':HeI_3889,'HeI_3889_err':HeI_3889_err,
                       'Hzet':Hzet,'Hzet_err':Hzet_err,'NeIII_3968':NeIII_3968,'NeIII_3968_err':NeIII_3968_err,
                       'Heps':Heps,'Heps_err':Heps_err,'Hdel':Hdel,'Hdel_err':Hdel_err,'Hgam':Hgam,'Hgam_err':Hgam_err,
                       'HeII_4687':HeII_4687,'HeII_4687_err':HeII_4687_err,'Hb':Hb,'Hb_err':Hb_err,
                       'OIII_4960':OIII_4960,'OIII_4960_err':OIII_4960_err,'OIII_5008':OIII_5008,
                       'OIII_5008_err':OIII_5008_err,'NI_5199':NI_5199,'NI_5199_err':NI_5199_err,
                       'NI_5201':NI_5201,'NI_5201_err':NI_5201_err,'HeI_5877':HeI_5877,'HeI_5877_err':HeI_5877_err,
                       'OI_6302':OI_6302,'OI_6302_err':OI_6302_err,'OI_6365':OI_6365,'OI_6365_err':OI_6365_err,
                       'NII_6549':NII_6549,'NII_6549_err':NII_6549_err,'Ha':Ha,'Ha_err':Ha_err,'NII_6585':NII_6585,
                       'NII_6585_err':NII_6585_err,'SII_6718':SII_6718,'SII_6718_err':SII_6718_err,'SII_6732':SII_6732,
                       'SII_6732_err':SII_6732_err,'HeI_7067':HeI_7067,'HeI_7067_err':HeI_7067_err,
                       'ArIII_7137':ArIII_7137,'ArIII_7137_err':ArIII_7137_err,'ArIII_7753':ArIII_7753,
                       'ArIII_7753_err':ArIII_7753_err,'Peta':Peta,'Peta_err':Peta_err,'SIII_9071':SIII_9071,
                       'SIII_9071_err':SIII_9071_err,'Pzet':Pzet,'Pzet_err':Pzet_err,'SIII_9533':SIII_9533,
                       'SIII_9533_err':SIII_9533_err,'Peps':Peps,'Peps_err':Peps_err,'CIII_1906':CIII_1906,
                       'CIII_1906_err':CIII_1906_err,'CIII_1909':CIII_1909,'CIII_1909_err':CIII_1909_err,
                       'CII_2325C':CII_2325C,'CII_2325C_err':CII_2325C_err,'CII_2325D':CII_2325D,
                       'CII_2325D_err':CII_2325D_err,'CII_2328':CII_2328,'CII_2328_err':CII_2328_err,
                       'FEIISTAR_2365':FEIISTAR_2365,'FEIISTAR_2365_err':FEIISTAR_2365_err,
                       'FEIISTAR_2396':FEIISTAR_2396,'FEIISTAR_2396_err':FEIISTAR_2396_err,
                       'NEIV_2423':NEIV_2423,'NEIV_2423_err':NEIV_2423_err,'NEIV_2425':NEIV_2425,
                       'NEIV_2425_err':NEIV_2425_err,'OII_2470':OII_2470,'OII_2470_err':OII_2470_err,
                       'FEIISTAR_2613':FEIISTAR_2613,'FEIISTAR_2613_err':FEIISTAR_2613_err,
                       'FEIISTAR_2626':FEIISTAR_2626,'FEIISTAR_2626_err':FEIISTAR_2626_err,
                       'FEIISTAR_2632':FEIISTAR_2632,'FEIISTAR_2632_err':FEIISTAR_2632_err,'MGII_2796':MGII_2796,
                       'MGII_2796_err':MGII_2796_err,'MGII_2803':MGII_2803,'MGII_2803_err':MGII_2803_err,
                       'HEI_2945':HEI_2945,'HEI_2945_err':HEI_2945_err,'OIII_3134' :OIII_3134,
                       'OIII_3134_err':OIII_3134_err ,'HeI_3189':HeI_3189,'HeI_3189_err':HeI_3189_err ,
                       'HeII_3204':HeII_3204,'HeII_3204_err':HeII_3204_err ,'NeV_3347':NeV_3347,
                       'NeV_3347_err':NeV_3347_err ,'NeV_3427':NeV_3427,'NeV_3427_err':NeV_3427_err ,
                       'SII_4070':SII_4070,'SII_4070_err':SII_4070_err ,'OIII_4364':OIII_4364,
                       'OIII_4364_err':OIII_4364_err ,'HeI_4473':HeI_4473,'HeI_4473_err':HeI_4473_err ,
                       'FeIII_4659':FeIII_4659,'FeIII_4659_err':FeIII_4659_err,'Z':z,'NeV':NeV,'NeV_err':NeV_err,
                       'Hb_ew':Hb_ew,'Hb_ew_err':Hb_ew_err,'NII_6549_ew':NII_6549_ew,'NII_6549_ew_err':NII_6549_ew_err,
                       'OIII_5008_ew':OIII_5008_ew,'OIII_5008_ew_err':OIII_5008_ew_err,'Ha_ew':Ha_ew,
                       'Ha_ew_err':Ha_ew_err,'OIII_4364_ew':OIII_4364_ew,'OIII_4364_ew_err':OIII_4364_ew_err,
                       'HeII_4687_ew':HeII_4687_ew,'HeII_4687_ew_err':HeII_4687_ew_err,'NeV_ew':NeV_ew,
                       'NeV_ew_err':NeV_ew_err,'OII_ew':OII_ew,'OII_ew_err':OII_ew_err})'''



#collumn creation for dataset 2 by Drake
#plate_drk = hdu2[1].data['PLATE'].byteswap().newbyteorder()
#mjd_drk = hdu2[1].data['MJD'].byteswap().newbyteorder()
#fiber_drk = hdu2[1].data['FIBERID'].byteswap().newbyteorder()
tag_drake = hdu2[1].data['PMF_String'].byteswap().newbyteorder()
logm = hdu2[1].data['LOGMSTAR'].byteswap().newbyteorder()
logm_err = hdu2[1].data['LOGMSTAR_ERR'].byteswap().newbyteorder()
logsfr = hdu2[1].data['LOGSFR'].byteswap().newbyteorder()
logsfr_err = hdu2[1].data['LOGSFR_ERR'].byteswap().newbyteorder()
code = hdu2[1].data['TARGET_CODE'].byteswap().newbyteorder()
#dataframe creation of Drake's data to get LOGM values which are not in my data
dfdrake = pd.DataFrame({'tag':tag_drake,'LOGM':logm,'LOGM_ERR':logm_err,'CODE':code,'LOGSFR':logsfr,'LOGSFR_ERR':logsfr_err})

dfdrake['tag'] = dfdrake["tag"].astype(str).str.replace('_','-')

# %%
#Checking columns in Drakes data
dfdrake
# Out:
#                       tag       LOGM  LOGM_ERR  CODE    LOGSFR  LOGSFR_ERR
# 0        03586-55181-0002  11.177167  0.021715  BLRG  0.986286    0.021715
# 1        03586-55181-0006  11.322493  0.021715  BLRG -0.453992    0.021715
# 2        03586-55181-0007  11.178451  0.021715  BLRG -1.381068    0.021715
# 3        03586-55181-0008  11.213365  0.021715  BLRG -1.346020    0.021715
# 4        03586-55181-0009  11.192256  0.021715  BLRG -2.864290    0.394043
# ...                   ...        ...       ...   ...       ...         ...
# 1893690  12547-58928-0985        NaN       NaN  MISC       NaN         NaN
# 1893691  12547-58928-0986        NaN       NaN  MISC       NaN         NaN
# 1893692  12547-58928-0988        NaN       NaN  MISC       NaN         NaN
# 1893693  12547-58928-0991        NaN       NaN  MISC       NaN         NaN
# 1893694  12547-58928-0994        NaN       NaN  MISC       NaN         NaN
#
# [1893695 rows x 6 columns]

# %%
#Checking columns in MY data
dfV12["str_fiber"] = dfV12["fiber"].astype(str).str.replace(
    r"^\d{1,4}$", lambda g: "{:0>4}".format(g.group(0)), regex=True
)
dfV12['str_plate'] = dfV12['plate'].astype(str)
dfV12['str_mjd'] = dfV12['mjd'].astype(str)
dfV12['tag'] = dfV12[['str_plate', 'str_mjd', 'str_fiber']].agg('-'.join, axis=1).str.zfill(16)
dfV12 = dfV12.drop(['plate','mjd','fiber','str_plate', 'str_mjd', 'str_fiber'],axis = 1)
dfV12
# Out:
#           OII_3727  OII_3727_err   OII_3729  OII_3729_err  NeIII_3869  \
# 0        12.028493      1.698636  14.131726      1.796210    0.470695
# 1         0.000000      4.459525  10.062956      4.433974    6.093426
# 2         0.000000      0.896005   2.340423      0.916299    0.000000
# 3         2.508159      1.208829   2.405458      1.188623    1.150341
# 4         0.000000      1.085114   0.123834      1.076473    0.000000
# ...            ...           ...        ...           ...         ...
# 1893690   4.596894      1.455530   4.334670      1.407271    1.934960
# 1893691   0.000000      4.987759   9.595968      5.050958    0.000000
# 1893692  20.308348      2.588283  17.848116      2.487901    4.297928
# 1893693   1.395790      2.808018  17.494390      2.902952    0.000000
# 1893694  23.349215      2.958364  10.085100      2.811192    0.483410
#
#          NeIII_3869_err  HeII_4687  HeII_4687_err         Hb    Hb_err  ...  \
# ...

# %%
#Merging Dataframes

df = dfV12.merge(dfdrake, on='tag')#.drop(columns=['PLATE_x', 'MJD_x', 'FIBER_x',  'PLATE_y','MJD_y', 'FIBER_y'])
df.to_csv(r"C:\Users\owenm\Documents\catalog_paper\summary_files\imp_lines.csv",index=False)
del dfV12
del dfdrake

# %%
df['tag']
# Out:
# 0          03586-55181-0002
# 1          03586-55181-0006
# 2          03586-55181-0007
# 3          03586-55181-0008
# 4          03586-55181-0009
#                  ...
# 1893690    12547-58928-0985
# 1893691    12547-58928-0986
# 1893692    12547-58928-0988
# 1893693    12547-58928-0991
# 1893694    12547-58928-0994
# Name: tag, Length: 1893695, dtype: object

# %%
#creating the columns that will acuatally be used in the diagnostic diagrams
df['OII'] = df['OII_3727']+ df['OII_3729']
df['OII_err'] = np.sqrt(df['OII_3727_err']**2+ df['OII_3729_err']**2)


#### ADD in the 5007 > 4959 CUT --- nevermind they are tied

# %%
matches = pd.read_csv(r"C:\Users\owenm\Documents\catalog_paper\summary_files\singlematch.csv")#'singlematch.csv')

# %%
matches
# Out:
#                     tag1              tag2
# 0       10000-57716-0009  10000-58514-0011
# 1       10000-58141-0007  10000-57346-0009
# 2       10000-58141-0007  10000-58514-0011
# 3       10000-58514-0011  10000-57346-0009
# 4       10000-57716-0009  10000-57346-0009
# ...                  ...               ...
# 505904   9611-58136-0998   9611-58107-0990
# 505905   9611-58136-0993   9611-58107-0991
# 505906   9611-58136-0997   9611-58107-0999
# 505907  10659-58161-0495   9611-58136-0613
# 505908  10657-58157-0204   9612-57801-0510
#
# [505909 rows x 2 columns]

# %%
matches.drop_duplicates()
matches = matches[matches['tag1'] != matches['tag2']]

# %%
matches['tag1'] = matches['tag1'].str.zfill(16)
matches['tag2'] = matches['tag2'].str.zfill(16)
matches['match'] = matches['tag1']+'|'+matches['tag2']

# %%
df['tag1'] = df['tag']
df['tag2'] = df['tag']

# %%
half1 = df.merge(matches,on='tag1').drop(columns=['tag1','tag2_x','tag2_y']).drop_duplicates()
half2 = df.merge(matches,on='tag2').drop(columns=['tag2','tag1_x','tag1_y']).drop_duplicates()

# %%
half2['match']
# Out:
# 0         03588-55184-0429|03586-55181-0006
# 1         04222-55444-0433|03586-55181-0006
# 2         04222-55444-0463|03586-55181-0007
# 3         04221-55443-0109|03586-55181-0008
# 4         04222-55444-0435|03586-55181-0011
#                         ...
# 485459    11704-58514-0973|11703-58526-0507
# 485460    11704-58514-0039|11703-58526-0531
# 485461    11704-58514-0998|11703-58526-0570
# 485462    11704-58514-0991|11703-58526-0571
# 485463    11704-58514-0993|11703-58526-0573
# Name: match, Length: 242491, dtype: object

# %%
import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in list(
                          locals().items())), key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))
# Out:
#                             df:  1.4 GiB
#                            _10:  1.0 GiB
#                             _9: 243.7 MiB
#                          half1: 177.2 MiB
#                          half2: 175.8 MiB
#                            ___: 116.5 MiB
#                            _12: 116.5 MiB
#                        matches: 102.3 MiB
#                             __: 61.8 MiB
#                            _15: 61.8 MiB

# %%
lst1 = matches['match'].to_numpy().tolist()
arr1 = np.array(lst1)
unispecs = np.unique(arr1)
print('unique spectra # = :',len(unispecs))
del matches
del df
#del ___
#del _12
#del _10
#del _9
# Out:
# unique spectra # = : 260637

# %%
final_matches = half1.merge(half2,on='match').drop_duplicates()

# %%
final_matches['match']
# Out:
# 0         03587-55182-0264|03586-55181-0028
# 1         03587-55182-0264|04221-55443-0116
# 2         03587-55182-0369|03586-55181-0173
# 3         03587-55182-0385|03586-55181-0179
# 4         03587-55182-0427|03586-55181-0215
#                         ...
# 232847    12545-58930-0920|03823-55534-0359
# 232848    12547-58928-0026|04735-55651-0293
# 232849    12547-58928-0221|04735-55651-0453
# 232850    12547-58928-0306|03822-55544-0105
# 232851    12547-58928-0531|03822-55544-0835
# Name: match, Length: 232852, dtype: object

# %%
final_matches.to_csv(r"C:\Users\owenm\Documents\catalog_paper\summary_files\saved_matched_fluxes.csv",index=False)

# %%
final_matches
# Out:
#         OII_3727_x  OII_3727_err_x  OII_3729_x  OII_3729_err_x  NeIII_3869_x  \
# 0        11.388681        3.121846    5.956603        3.122015      0.000000
# 1        11.388681        3.121846    5.956603        3.122015      0.000000
# 2         0.591476        9.729460    5.895137        9.658261      0.000000
# 3         2.389697        0.947938    0.000000        0.928282      0.481390
# 4         0.000000        2.221228    7.199222        2.252865      0.000000
# ...            ...             ...         ...             ...           ...
# 232847    1.465204        2.177397    0.268869        1.878026      0.000000
# 232848    0.000000        1.850197    1.230471        2.075190      0.000000
# 232849   12.774409        2.299267   16.776253        2.116845      2.810525
# 232850    0.981760        1.105361    0.000000        1.115385      0.035073
# 232851    3.572726        2.308562    0.000000        2.332145      0.000000
#
# ...

# %%
break
# Out:
#   Cell In[27], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
int(df['tag'][0].split('_')[1])

# %%
plates = []
mjds = []
for tag in df['tag']:
    plate = int(tag.split('_')[0])
    mjd = int(tag.split('_')[1])
    plates.append(plate)
    mjds.append(mjd)

# %%
df['plate'] = plates
df['mjd'] = mjds
df

# %%
lines = ['Hb', 'NeV','OII','NII','OIII','Halpha','OIII_4364', 'HeII_4687']
line = lines[6]
df['SNR'] =  (np.divide(df[line],df[line+'_err']))

# %%
platedf = df.groupby(['plate']).SNR.median().reset_index(name='avg_S/N')
mjddf = df.groupby(['mjd']).SNR.median().reset_index(name='avg_S/N')

# %%
plt.scatter(df['plate'],df['SNR'],s=1,c='k',alpha = 0.15)
plt.plot(platedf['plate'],platedf['avg_S/N'])
plt.ylim(0,15)
plt.show()

# %%
import scipy
import scipy.ndimage
plt.figure(figsize = [11,8.5])

plt.scatter(df['mjd'],df['SNR'],s=1,c='k',alpha = 0.15)
plt.plot(mjddf['mjd'],scipy.ndimage.median_filter(mjddf['avg_S/N'], size=(5)),lw=3,c='r',label ='Smoothed Median Signal to Noise')
plt.xlabel('MJD')
plt.ylabel(line+' S/N')
plt.ylim(0,5)

plt.legend(loc=1)
plt.savefig(r"C:\Users\owenm\Documents\catalog_paper\\"+line+'_snr_vs_date.png',bbox_inches='tight')
plt.show()
